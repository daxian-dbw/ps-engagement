# %%
import requests
from datetime import datetime, timedelta

# %%
# --- CONFIGURATION ---
GITHUB_TOKEN = "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"
TARGET_OWNER = "PowerShell"
TARGET_REPO = "PowerShell"
TARGET_REPO_FULL = f"{TARGET_OWNER}/{TARGET_REPO}"
MAINTAINERS = ["daxian-dbw"] # Add your usernames here
DAYS_BACK = 30  # How far back to look?

# %%
# --- GRAPHQL QUERY ---
QUERY = """
query($username: String!, $count: Int = 100) {
  user(login: $username) {
    issueComments(last: $count) {
      nodes {
        createdAt
        url
        issue {
          repository {
            nameWithOwner
          }
          number
          title
        }
      }
    }
  }
}
"""

# %%
def run_query(username):
    url = 'https://api.github.com/graphql'
    headers = {'Authorization': f'Bearer {GITHUB_TOKEN}'}
    
    variables = {
        'username': username,
        'count': 100
    }
    
    response = requests.post(url, json={'query': QUERY, 'variables': variables}, headers=headers)
    
    if response.status_code == 200:
        result = response.json()
        # Filter for the target repo
        if 'data' in result and 'user' in result['data'] and result['data']['user']:
            comments = result['data']['user']['issueComments']['nodes']
            filtered = [c for c in comments if c['issue']['repository']['nameWithOwner'] == TARGET_REPO_FULL]
            return filtered
        return []
    else:
        raise Exception(f"Query failed: {response.status_code} {response.text}")


def parse_date(date_str):
    return datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")

# %%
# --- GRAPHQL QUERY WITH PAGINATION ---
QUERY_PAGINATED = """
## The default order for 'issueComments' in the GitHub GraphQL API is typically 
## sorted by creation time in ascending order (oldest comments first).
## So, I need to use `last` and `before` to get the most recent records first.
query($username: String!, $count: Int = 100, $before: String) {
  user(login: $username) {
    issueComments(last: $count, before: $before) {
      pageInfo {
        hasPreviousPage
        startCursor
      }
      nodes {
        publishedAt
        url
        issue {
          author {
            login
          }
          repository {
            nameWithOwner
          }
          publishedAt
          number
          title
        }
        pullRequest {
          merged
        }
      }
    }
  }
}
"""

# %%
def run_query_paginated(username, max_comments=None):
    """
    Fetch issue comments for a user with pagination support.
    
    Args:
        username: GitHub username
        max_comments: Maximum number of comments to fetch (None = all available)
    
    Returns:
        List of comments filtered for TARGET_REPO_FULL
    """
    url = 'https://api.github.com/graphql'
    headers = {'Authorization': f'Bearer {GITHUB_TOKEN}'}
    
    all_comments = []
    has_more = True
    cursor = None
    
    while has_more:
        variables = {
            'username': username,
            'count': 100
        }
        
        if cursor:
            variables['before'] = cursor
        
        response = requests.post(url, json={'query': QUERY_PAGINATED, 'variables': variables}, headers=headers)
        
        if response.status_code != 200:
            raise Exception(f"Query failed: {response.status_code} {response.text}")
        
        result = response.json()
        
        if 'data' not in result or 'user' not in result['data'] or not result['data']['user']:
            break
        
        issue_comments = result['data']['user']['issueComments']
        comments = issue_comments['nodes']
        page_info = issue_comments['pageInfo']
        
        # Filter for the target repo
        filtered = [c for c in comments if c['issue']['repository']['nameWithOwner'] == TARGET_REPO_FULL]
        all_comments.extend(filtered)
        
        # Check if we should continue
        has_more = page_info['hasPreviousPage']
        cursor = page_info['startCursor']
        
        # Stop if we've reached the max_comments limit
        if max_comments and len(all_comments) >= max_comments:
            all_comments = all_comments[:max_comments]
            break
    
    return all_comments

# %%
run_query_paginated('daxian-dbw', 50)
# Out:
# [{'publishedAt': '2025-09-30T17:01:27Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26086#issuecomment-3353065167',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-23T20:12:42Z',
#    'number': 26086,
#    'title': 'Allow opt-out of the named-pipe listener using an environment variable'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T17:31:22Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26086#issuecomment-3353175169',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-23T20:12:42Z',
#    'number': 26086,
#    'title': 'Allow opt-out of the named-pipe listener using an environment variable'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T18:31:35Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26091#issuecomment-3353344177',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-24T18:09:52Z',
#    'number': 26091,
#    'title': 'Mark the 3 consistently failing tests as pending to unblock PRs'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T19:02:50Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26086#issuecomment-3353438704',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-23T20:12:42Z',
#    'number': 26086,
#    'title': 'Allow opt-out of the named-pipe listener using an environment variable'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T19:03:07Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26118#issuecomment-3353439626',
#   'issue': {'author': {'login': 'andyleejordan'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-29T20:39:56Z',
#    'number': 26118,
#    'title': 'Remove `IsScreenReaderActive()` check'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T19:11:55Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26120#issuecomment-3353469194',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-30T05:12:54Z',
#    'number': 26120,
#    'title': 'Remove `ThreadJob` module and update `PSReadLine` to 2.4.4-beta4'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T20:46:43Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26124#issuecomment-3353752064',
#   'issue': {'author': {'login': 'pwshBot'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-30T20:11:00Z',
#    'number': 26124,
#    'title': '[master] Update branch for release'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-09-30T20:50:21Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26105#issuecomment-3353761282',
#   'issue': {'author': {'login': 'pwshBot'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-28T13:18:55Z',
#    'number': 26105,
#    'title': 'Update outdated package references'},
#   'pullRequest': {'merged': False}},
#  {'publishedAt': '2025-10-01T17:21:39Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26129#issuecomment-3357361149',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-01T17:12:18Z',
#    'number': 26129,
#    'title': "Update 'ThirdPartyNotices.txt' for v7.6.0-preview.5 release"},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-01T19:21:10Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/25590#issuecomment-3357812187',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-05-21T19:42:28Z',
#    'number': 25590,
#    'title': 'Remove the use of Windows PowerShell ETW provider id and update `PSDiagnostics` module to work for PowerShell 7'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-01T22:49:18Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26132#issuecomment-3358422818',
#   'issue': {'author': {'login': 'anamnavi'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-01T21:43:05Z',
#    'number': 26132,
#    'title': 'add CodeQL suppressions for UpdatableHelp and NativeCommandProcessor methods'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-01T22:53:27Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26133#issuecomment-3358431698',
#   'issue': {'author': {'login': 'anamnavi'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-01T21:51:38Z',
#    'number': 26133,
#    'title': 'add CodeQL suppressions for UpdatableHelp and NativeCommandProcessor methods'},
#   'pullRequest': {'merged': False}},
#  {'publishedAt': '2025-10-01T23:08:34Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26126#issuecomment-3358460442',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-09-30T22:50:29Z',
#    'number': 26126,
#    'title': 'Update ChangeLog for v7.6.0-preview.5 release'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-02T00:46:50Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26135#issuecomment-3358635585',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-02T00:29:35Z',
#    'number': 26135,
#    'title': "Replace 'ThreadJob' with 'Microsoft.PowerShell.ThreadJob'"},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-02T17:30:45Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26138#issuecomment-3362287113',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-02T17:21:34Z',
#    'number': 26138,
#    'title': 'Fix the task name to not use the pre-release task'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-09T22:17:40Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26158#issuecomment-3387646579',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-07T21:23:13Z',
#    'number': 26158,
#    'title': 'Update `metadata.json` for v7.6.0-preview.5 release'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-10T20:25:59Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26178#issuecomment-3392218815',
#   'issue': {'author': {'login': 'jshigetomi'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T19:39:12Z',
#    'number': 26178,
#    'title': 'Fix Automated Store Publishing, .NET Resolution, Update Linux Image, and Changelog Link Generation'},
#   'pullRequest': {'merged': False}},
#  {'publishedAt': '2025-10-10T22:09:27Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26180#issuecomment-3392458667',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T21:29:47Z',
#    'number': 26180,
#    'title': 'Merge the v7.6.0-preview.5 release branch back to master'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-10T22:28:05Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26180#issuecomment-3392485611',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T21:29:47Z',
#    'number': 26180,
#    'title': 'Merge the v7.6.0-preview.5 release branch back to master'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-10T22:53:16Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26180#issuecomment-3392521780',
#   'issue': {'author': {'login': 'daxian-dbw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T21:29:47Z',
#    'number': 26180,
#    'title': 'Merge the v7.6.0-preview.5 release branch back to master'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-10T23:10:36Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26178#issuecomment-3392545334',
#   'issue': {'author': {'login': 'jshigetomi'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T19:39:12Z',
#    'number': 26178,
#    'title': 'Fix Automated Store Publishing, .NET Resolution, Update Linux Image, and Changelog Link Generation'},
#   'pullRequest': {'merged': False}},
#  {'publishedAt': '2025-10-20T23:06:10Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26179#issuecomment-3424045482',
#   'issue': {'author': {'login': 'kMitty'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-10T21:16:27Z',
#    'number': 26179,
#    'title': 'Wrong static constructor run ordering of derived class'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-21T16:45:31Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26261#issuecomment-3427656939',
#   'issue': {'author': {'login': 'alirobe'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-21T06:40:04Z',
#    'number': 26261,
#    'title': 'winget version does not match release version'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-22T20:01:46Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3434017346',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-22T23:06:58Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26261#issuecomment-3434480184',
#   'issue': {'author': {'login': 'alirobe'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-21T06:40:04Z',
#    'number': 26261,
#    'title': 'winget version does not match release version'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-23T18:00:05Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26277#issuecomment-3438395475',
#   'issue': {'author': {'login': 'teramako'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T16:39:50Z',
#    'number': 26277,
#    'title': '`[System.Management.Automation.CompletionCompleters]::CompleteFilename("")` throws NullReferenceException'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-23T18:37:12Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26286#issuecomment-3438553416',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-23T05:49:45Z',
#    'number': 26286,
#    'title': 'Fix NullReferenceException in CompleteFilename when called with empty string'},
#   'pullRequest': {'merged': False}},
#  {'publishedAt': '2025-10-23T22:23:16Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26283#issuecomment-3439469275',
#   'issue': {'author': {'login': 'AaronMargosis'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T22:54:52Z',
#    'number': 26283,
#    'title': 'Get-AuthenticodeSignature fails on long file paths (greater than approx. 255 characters)'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-27T17:15:11Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26295#issuecomment-3452447880',
#   'issue': {'author': {'login': 'vaxtalastus-web'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-24T07:56:55Z',
#    'number': 26295,
#    'title': 'Buggy UI moving parts of pasted code into random areas'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-27T17:36:45Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26311#issuecomment-3452534944',
#   'issue': {'author': {'login': 'cuanl-cd'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-27T16:57:09Z',
#    'number': 26311,
#    'title': 'Azure Automation - PowerShell 7 - Linux Hybrid Runbook Worker - Incorrect Parameter Order'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-27T18:09:58Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/25865#issuecomment-3452658229',
#   'issue': {'author': {'login': 'RichardSlater'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-08-15T11:40:50Z',
#    'number': 25865,
#    'title': 'Unable to install 7.5.4 on Debian 13 (Trixie) due to unmet dependency on libicu[74|72|70|69|68|67|66|65|63|60|57|55|52]'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-27T18:28:55Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26306#issuecomment-3452726812',
#   'issue': {'author': {'login': 'xtqqczze'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-26T20:55:36Z',
#    'number': 26306,
#    'title': 'Avoid Regex in DscClassCache.CreateKeywordFromCimClass'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-27T21:18:52Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3453378225',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-28T00:06:54Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3453881515',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-28T16:54:09Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3457503078',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-28T18:26:57Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3457899983',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-28T20:17:42Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3458313304',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-28T22:51:51Z',
#   'url': 'https://github.com/PowerShell/PowerShell/pull/26281#issuecomment-3458869765',
#   'issue': {'author': {'login': 'copilot-swe-agent'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-22T19:59:55Z',
#    'number': 26281,
#    'title': 'Remove usage of fpm for DEB package generation'},
#   'pullRequest': {'merged': True}},
#  {'publishedAt': '2025-10-29T17:28:27Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26325#issuecomment-3462796345',
#   'issue': {'author': {'login': 'michellejazmin'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-28T22:26:45Z',
#    'number': 26325,
#    'title': 'Unable to update to version 7.5.4.0 with winget: "install technology is different from the current version installed"'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-29T18:32:52Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26317#issuecomment-3463130994',
#   'issue': {'author': {'login': 'steve02081504'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-28T04:59:43Z',
#    'number': 26317,
#    'title': 'Fatal error. System.AccessViolationException: Attempted to read or write protected memory.'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-29T18:53:17Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26317#issuecomment-3463279545',
#   'issue': {'author': {'login': 'steve02081504'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-28T04:59:43Z',
#    'number': 26317,
#    'title': 'Fatal error. System.AccessViolationException: Attempted to read or write protected memory.'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-30T18:14:12Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26352#issuecomment-3469399533',
#   'issue': {'author': {'login': 'karman-docker'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-30T06:29:55Z',
#    'number': 26352,
#    'title': 'GetACL works only first time'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-30T18:31:03Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26354#issuecomment-3469486541',
#   'issue': {'author': {'login': 'iainfm'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-30T09:45:25Z',
#    'number': 26354,
#    'title': 'New-CIPolicy (ConfigCI) errors when creating a file path rule'},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-30T23:27:55Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/20222#issuecomment-3470699409',
#   'issue': {'author': {'login': 'futuremotiondev'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2023-09-09T07:01:29Z',
#    'number': 20222,
#    'title': "The 'Get-ImageDimensions' command was found in the module 'VSYSFileOps', but the module could not be loaded due to the following error: [An item with the same key has already been added. Key: -813443191]"},
#   'pullRequest': None},
#  {'publishedAt': '2025-10-31T01:49:44Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26352#issuecomment-3470987895',
#   'issue': {'author': {'login': 'karman-docker'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-10-30T06:29:55Z',
#    'number': 26352,
#    'title': 'GetACL works only first time'},
#   'pullRequest': None},
#  {'publishedAt': '2025-11-04T21:02:57Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26374#issuecomment-3488003704',
#   'issue': {'author': {'login': 'kiroma'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-11-04T13:45:07Z',
#    'number': 26374,
#    'title': 'Launched subshell with -Command finishes with an error `PipelineStoppedException`'},
#   'pullRequest': None},
#  {'publishedAt': '2025-11-10T19:59:35Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/21232#issuecomment-3513684439',
#   'issue': {'author': {'login': 'jprpicw'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2024-02-15T10:00:39Z',
#    'number': 21232,
#    'title': ".NET Can't import ActiveDirectory module, works in Powershell"},
#   'pullRequest': None},
#  {'publishedAt': '2025-11-11T22:35:56Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26381#issuecomment-3518969200',
#   'issue': {'author': {'login': 'sba923'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-11-04T21:24:56Z',
#    'number': 26381,
#    'title': 'Fatal exception in PowerShell 7.5.4'},
#   'pullRequest': None},
#  {'publishedAt': '2025-11-17T19:48:18Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/25865#issuecomment-3543585352',
#   'issue': {'author': {'login': 'RichardSlater'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-08-15T11:40:50Z',
#    'number': 25865,
#    'title': 'Unable to install 7.5.4 on Debian 13 (Trixie) due to unmet dependency on libicu[74|72|70|69|68|67|66|65|63|60|57|55|52]'},
#   'pullRequest': None},
#  {'publishedAt': '2025-11-17T21:23:34Z',
#   'url': 'https://github.com/PowerShell/PowerShell/issues/26453#issuecomment-3543896974',
#   'issue': {'author': {'login': 'kfsone'},
#    'repository': {'nameWithOwner': 'PowerShell/PowerShell'},
#    'publishedAt': '2025-11-15T01:29:35Z',
#    'number': 26453,
#    'title': 'DirectoryInfo "User" field width handling is bad (Mac/Lin/Wsl)'},
#   'pullRequest': None}]

# %%
# --- GRAPHQL QUERY FOR PR REVIEWS WITH PAGINATION ---
PR_REVIEW_QUERY_PAGINATED = """
## The pullRequestReviewContributions field is a connection that orders contributions 
## by default in descending chronological order (most recent contributions first).
## So, I need to use `first` and `after` to get the most recent records first.
query($username: String!, $count: Int = 100, $after: String) {
  user(login: $username) {
    contributionsCollection {
      pullRequestReviewContributions(first: $count, after: $after) {
        pageInfo {
          hasPreviousPage
          startCursor
        }
        nodes {
          occurredAt
          pullRequest {
            author {
              login
            }
            publishedAt
            number
            title
            merged
          }
          pullRequestReview {
            url
            state
          }
          repository {
            nameWithOwner
          }
        }
      }
    }
  }
}
"""

# %%
def run_pr_review_query_paginated(username, max_reviews=None):
    """
    Fetch pull request reviews for a user with pagination support.
    
    Args:
        username: GitHub username
        max_reviews: Maximum number of reviews to fetch (None = all available)
    
    Returns:
        List of reviews filtered for TARGET_REPO_FULL
    """
    url = 'https://api.github.com/graphql'
    headers = {'Authorization': f'Bearer {GITHUB_TOKEN}'}
    
    all_reviews = []
    has_more = True
    cursor = None
    
    while has_more:
        variables = {
            'username': username,
            'count': 100
        }
        
        if cursor:
            variables['after'] = cursor
        
        response = requests.post(url, json={'query': PR_REVIEW_QUERY_PAGINATED, 'variables': variables}, headers=headers)
        
        if response.status_code != 200:
            raise Exception(f"Query failed: {response.status_code} {response.text}")
        
        result = response.json()
        
        if 'data' not in result or 'user' not in result['data'] or not result['data']['user']:
            break
        
        contributions = result['data']['user']['contributionsCollection']['pullRequestReviewContributions']
        reviews = contributions['nodes']
        page_info = contributions['pageInfo']
        
        # Filter for the target repo
        filtered = [r for r in reviews if r['repository']['nameWithOwner'] == TARGET_REPO_FULL]
        all_reviews.extend(filtered)
        
        # Check if we should continue
        has_more = page_info['hasPreviousPage']
        cursor = page_info['startCursor']
        
        # Stop if we've reached the max_reviews limit
        if max_reviews and len(all_reviews) >= max_reviews:
            all_reviews = all_reviews[:max_reviews]
            break
    
    return all_reviews

# %%
run_pr_review_query_paginated('daxian-dbw', 30)
# Out:
# [{'occurredAt': '2025-12-08T23:21:41Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-08T23:19:31Z',
#    'number': 26590,
#    'title': '[release/v7.6] Update Microsoft.PowerShell.PSResourceGet to v1.2.0-preview5',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26590#pullrequestreview-3554509627',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-08T20:15:23Z',
#   'pullRequest': {'author': {'login': 'dkaszews'},
#    'publishedAt': '2022-08-31T17:28:25Z',
#    'number': 18003,
#    'title': 'Make prompt colors configurable',
#    'merged': False},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/18003#pullrequestreview-3553807109',
#    'state': 'CHANGES_REQUESTED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-05T23:36:17Z',
#   'pullRequest': {'author': {'login': 'TravisEz13'},
#    'publishedAt': '2025-11-25T22:05:24Z',
#    'number': 26530,
#    'title': '[release/v7.6] Add merge conflict marker detection to linux-ci workflow and refactor existing actions to use reusable get-changed-files action',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26530#pullrequestreview-3546735104',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-05T19:39:42Z',
#   'pullRequest': {'author': {'login': 'TravisEz13'},
#    'publishedAt': '2025-11-20T18:58:34Z',
#    'number': 26502,
#    'title': '[release/v7.6] Make the experimental feature `PSFeedbackProvider` stable',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26502#pullrequestreview-3546185506',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-05T19:02:33Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-05T17:58:42Z',
#    'number': 26576,
#    'title': '[release/v7.6] Update the macos package name for preview releases to match the previous pattern',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26576#pullrequestreview-3546053214',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-05T19:02:24Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-05T00:07:41Z',
#    'number': 26573,
#    'title': '[release/v7.6] Add rebuild branch support with conditional MSIX signing',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26573#pullrequestreview-3546052362',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-04T23:54:21Z',
#   'pullRequest': {'author': {'login': 'TravisEz13'},
#    'publishedAt': '2025-11-25T22:59:59Z',
#    'number': 26532,
#    'title': '[release/v7.6] Improve ADO package build and validation across platforms',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26532#pullrequestreview-3542587482',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-04T18:38:16Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-04T18:14:22Z',
#    'number': 26572,
#    'title': '[release/v7.6] Add Delimiter parameter to Get-Clipboard',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26572#pullrequestreview-3541527307',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-04T18:37:53Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-04T18:09:59Z',
#    'number': 26571,
#    'title': '[release/v7.6] Properly Expand Aliases to their actual ResolvedCommand',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26571#pullrequestreview-3541525850',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-03T01:01:40Z',
#   'pullRequest': {'author': {'login': 'dependabot'},
#    'publishedAt': '2025-12-02T07:04:56Z',
#    'number': 26554,
#    'title': 'Bump github/codeql-action from 4.31.5 to 4.31.6',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26554#pullrequestreview-3532716156',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:55:39Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:28:11Z',
#    'number': 26564,
#    'title': '[release/v7.6] Close pipe client handles after creating the child ssh process',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26564#pullrequestreview-3532589829',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:54:39Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:23:42Z',
#    'number': 26563,
#    'title': '[release/v7.6] Mirror .NET/runtime ICU version range in PowerShell',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26563#pullrequestreview-3532587571',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:54:29Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:20:50Z',
#    'number': 26562,
#    'title': '[release/v7.6] Update the macos package name for preview releases to match the previous pattern',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26562#pullrequestreview-3532587234',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:54:13Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:16:07Z',
#    'number': 26561,
#    'title': '[release/v7.6] Fix condition syntax for StoreBroker package tasks in MSIX pipeline',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26561#pullrequestreview-3532586577',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:53:58Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:11:09Z',
#    'number': 26560,
#    'title': '[release/v7.6] Fix template path for rebuild branch check in package.yml',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26560#pullrequestreview-3532586233',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:53:36Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:07:23Z',
#    'number': 26559,
#    'title': '[release/v7.6] Add rebuild branch support with conditional MSIX signing',
#    'merged': False},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26559#pullrequestreview-3532585685',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:53:23Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T23:02:32Z',
#    'number': 26558,
#    'title': '[release/v7.6] Move package validation to package pipeline',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26558#pullrequestreview-3532585387',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:52:34Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T22:55:51Z',
#    'number': 26557,
#    'title': '[release/v7.6] Optimize/split windows package signing',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26557#pullrequestreview-3532584219',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-12-02T23:52:17Z',
#   'pullRequest': {'author': {'login': 'adityapatwardhan'},
#    'publishedAt': '2025-12-02T22:45:50Z',
#    'number': 26556,
#    'title': '[release/v7.6] Fix merge conflict checker for empty file lists and filter *.cs files',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26556#pullrequestreview-3532583770',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-25T18:33:30Z',
#   'pullRequest': {'author': {'login': 'dependabot'},
#    'publishedAt': '2025-11-25T07:04:30Z',
#    'number': 26527,
#    'title': 'Bump github/codeql-action from 4.31.4 to 4.31.5',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26527#pullrequestreview-3506345642',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-21T22:19:28Z',
#   'pullRequest': {'author': {'login': 'dependabot'},
#    'publishedAt': '2025-11-21T07:05:12Z',
#    'number': 26505,
#    'title': 'Bump actions/checkout from 5 to 6',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26505#pullrequestreview-3494569003',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-21T22:19:01Z',
#   'pullRequest': {'author': {'login': 'logiclrd'},
#    'publishedAt': '2025-11-20T16:27:28Z',
#    'number': 26500,
#    'title': 'Improve error message from Start-NativeExecution',
#    'merged': False},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26500#pullrequestreview-3494568013',
#    'state': 'COMMENTED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-21T22:06:35Z',
#   'pullRequest': {'author': {'login': 'logiclrd'},
#    'publishedAt': '2025-11-21T16:54:05Z',
#    'number': 26507,
#    'title': 'Explain `-UseNuGetOrg` in build documentation',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26507#pullrequestreview-3494527254',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-20T23:07:37Z',
#   'pullRequest': {'author': {'login': 'dependabot'},
#    'publishedAt': '2025-11-19T07:04:28Z',
#    'number': 26484,
#    'title': 'Bump github/codeql-action from 4.31.3 to 4.31.4',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26484#pullrequestreview-3490445276',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-20T22:56:40Z',
#   'pullRequest': {'author': {'login': 'TravisEz13'},
#    'publishedAt': '2025-11-19T22:10:34Z',
#    'number': 26490,
#    'title': '[release/v7.6] Make some experimental features stable',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26490#pullrequestreview-3490381009',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-18T01:24:02Z',
#   'pullRequest': {'author': {'login': 'pwshBot'},
#    'publishedAt': '2025-11-13T23:12:58Z',
#    'number': 26448,
#    'title': '[master] Update branch for release',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26448#pullrequestreview-3475138465',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-17T23:56:12Z',
#   'pullRequest': {'author': {'login': 'yotsuda'},
#    'publishedAt': '2025-11-17T22:17:42Z',
#    'number': 26469,
#    'title': 'Respect -UseWindowsPowerShell:$false in New-PSSession',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26469#pullrequestreview-3474970975',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-17T19:51:48Z',
#   'pullRequest': {'author': {'login': 'dependabot'},
#    'publishedAt': '2025-11-14T07:04:50Z',
#    'number': 26451,
#    'title': 'Bump github/codeql-action from 4.31.2 to 4.31.3',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26451#pullrequestreview-3474339639',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-12T00:42:54Z',
#   'pullRequest': {'author': {'login': 'copilot-swe-agent'},
#    'publishedAt': '2025-11-11T22:20:00Z',
#    'number': 26426,
#    'title': 'Standardize template references to use absolute paths across .pipelines folder',
#    'merged': False},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26426#pullrequestreview-3450744249',
#    'state': 'DISMISSED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}},
#  {'occurredAt': '2025-11-12T00:42:10Z',
#   'pullRequest': {'author': {'login': 'TravisEz13'},
#    'publishedAt': '2025-11-11T22:53:47Z',
#    'number': 26427,
#    'title': 'Fix condition syntax for StoreBroker package tasks in MSIX pipeline',
#    'merged': True},
#   'pullRequestReview': {'url': 'https://github.com/PowerShell/PowerShell/pull/26427#pullrequestreview-3450741935',
#    'state': 'APPROVED'},
#   'repository': {'nameWithOwner': 'PowerShell/PowerShell'}}]
